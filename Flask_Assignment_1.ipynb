# %% [markdown]
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.
# #### Q3. What is App routing in Flask? Why do we use app routes?
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
#     route to show the following details:
#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999
#     Attach the screenshot of the output in Jupyter Notebook.
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# ## Answers

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# #### Flask Framework :===>
# Flask is a popular and lightweight web framework for building web applications in Python. It provides a simple and flexible way to develop web applications by providing the essential tools and libraries needed for web development.

# %% [markdown]
# #### Advantage

# %% [markdown]
# 1. Simplicity
# --------------------
# Flask is known for its simplicity and ease of use.
#
# 2. Lightweight and Flexible
# ------------------------------
# Flask is a lightweight framework that allows developers to choose and add only the necessary components and extensions based on their specific requirements.
#
# 3. Extensibility
# ----------------------
# Flask provides a range of extensions that developers can use to enhance their applications. These extensions offer additional functionalities such as database integration, authentication, form validation, caching, and more.
#
# 4. Scalability
# -------------------
# Flask allows developers to build scalable applications by utilizing its modular structure and extension ecosystem. Developers can optimize and scale their applications based on specific needs, making Flask suitable for small projects as well as large, complex applications.
#
# 5. Integration with Other Technologies:
# --------------------------------------------
# Flask seamlessly integrates with other technologies commonly used in web development, such as SQL databases (e.g., SQLAlchemy), template engines (e.g., Jinja2), and authentication mechanisms (e.g., OAuth).

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/Hello')
def hello():
    return "Hello World !"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (11).png](attachment:a901bc03-27f5-42a0-8e46-a07d1dfa1454.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# @app.route() :===> Is a decorator function which is used to map the specific URL.
# These routes determine how the application responds to different HTTP requests from clients. Flask uses the concept of decorators to define routes, where a decorator is a way to modify or enhance the behavior of a function.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
#     route to show the following details:
#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999
#     Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/home')
def Home():
    return "Welcome to ABC Corporation"

@app.route('/a')
def display():
    return ''' Company Name: ABC Corporation
               Location: India
               Contact Detail: 999-999-9999'''


if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (12).png](attachment:823234ae-4eac-4e18-a2ab-21a1a65878af.png)

# %% [markdown]
# ![Screenshot (13).png](attachment:90129fbc-97c4-4c91-a7b9-9859d42a0ac4.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# url_for() : ===> In Flask, the url_for() function is used for URL building. It is a built-in function provided by Flask that generates a URL for a given route based on the associated view function. The url_for() function takes the name of the view function as an argument and returns the corresponding URL.
#
# Note that in order to use url_for() outside of the request context, we need to create a test request context using with app.test_request_context().The url_for() function is useful when building links within your Flask application.

# %%
from flask import Flask ,url_for

app = Flask(__name__)

@app.route('/home')
def Home():
    return "Welcome to ABC Corporation"

@app.route('/a')
def display():
    return ''' Company Name: ABC Corporation
               Location: India
               Contact Detail: 999-999-9999'''


if __name__=="__main__":
    app.run(host="0.0.0.0")
    with app.test_request_context():
        print(url_for('Home'))
